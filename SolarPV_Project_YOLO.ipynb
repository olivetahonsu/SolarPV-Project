# %% [markdown]
# <a href="https://colab.research.google.com/github/olivetahonsu/SolarPV-Project/blob/main/SolarPV_Project_YOLO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World!")

print("David Ahonsu is here.")
# Out:
# Hello World!
# David Ahonsu is here.
